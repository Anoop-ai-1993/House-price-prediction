# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/output.csv')

# %%
df.head(5)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0     0          3        1340              0        59             9
# 1     4          5        3370            280        93             0
# 2     0          4        1930              0        48             0
# 3     0          4        1000           1000        51             0
# 4     0          4        1140            800        38            22

# %% [markdown]
# Drop the extra columns

# %%
df=df.drop(columns=['date','street','country','city','statezip'])

# %% [markdown]
# year of built and year of renovate change into how old it is

# %%
df['yr_built']=(df['yr_built']-2014).abs()

# %% [markdown]
# year_renovate change to years margin

# %%
def year_convert(year):
  if year!=0:
    return (2014-year)
  else:
    return year

# %%
df['yr_renovated']=df['yr_renovated'].apply(year_convert)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split

# %%
SS=StandardScaler()

# %% [markdown]
# Standard scale

# %%
x_train=SS.fit_transform(x_train)

# %%
col=x_train.columns

# %%
pd.DataFrame(x_train,columns=col)

# %%
LR=LinearRegression()

# %%
x=df.drop(columns='price')
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_test.shape
# Out:
# (920, 12)

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_train)
y_test_pred=LR.predict(x_test)

# %%
r2_score(y_train,y_pred)
# Out:
# 0.4110790109707684

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.05625822549078574
